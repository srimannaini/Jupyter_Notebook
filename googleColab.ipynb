# %% [markdown]
# <a href="https://colab.research.google.com/github/srimannaini/Jupyter_Notebook/blob/main/googleColab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## This is title

# %%
print("Hello World")
# Out:
# Hello World

# %%
3+6
# Out:
# 9

# %% [markdown]
# # Public Link

# %%
# !wget https://www.stats.govt.nz/assets/Uploads/Annual-enterprise-survey/Annual-enterprise-survey-2020-financial-year-provisional/Download-data/annual-enterprise-survey-2020-financial-year-provisional-csv.csv
# Out:
# --2021-12-07 17:16:35--  https://www.stats.govt.nz/assets/Uploads/Annual-enterprise-survey/Annual-enterprise-survey-2020-financial-year-provisional/Download-data/annual-enterprise-survey-2020-financial-year-provisional-csv.csv
# Resolving www.stats.govt.nz (www.stats.govt.nz)... 45.60.11.104
# Connecting to www.stats.govt.nz (www.stats.govt.nz)|45.60.11.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5881081 (5.6M) [text/csv]
# Saving to: ‘annual-enterprise-survey-2020-financial-year-provisional-csv.csv’
#
# annual-enterprise-s 100%[===================>]   5.61M  2.63MB/s    in 2.1s
#
# 2021-12-07 17:16:39 (2.63 MB/s) - ‘annual-enterprise-survey-2020-financial-year-provisional-csv.csv’ saved [5881081/5881081]

# %%
# !ls
# Out:
#  annual-enterprise-survey-2020-financial-year-provisional-csv.csv  'url?sa=i'
#  sample_data

# %%
import pandas as pd

# %%
pd.read_csv("annual-enterprise-survey-2020-financial-year-provisional-csv.csv").head()
# Out:
#    Year  ...                             Industry_code_ANZSIC06
# 0  2020  ...  ANZSIC06 divisions A-S (excluding classes K633...
# 1  2020  ...  ANZSIC06 divisions A-S (excluding classes K633...
# 2  2020  ...  ANZSIC06 divisions A-S (excluding classes K633...
# 3  2020  ...  ANZSIC06 divisions A-S (excluding classes K633...
# 4  2020  ...  ANZSIC06 divisions A-S (excluding classes K633...
#
# [5 rows x 10 columns]

# %% [markdown]
# # Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!ln -s /content/gdrive/My\ Drive/ /MyDrive

# %%
# %cd /content/drive/MyDrive/yolov4piford
# Out:
# /content/drive/MyDrive/yolov4piford

# %% [markdown]
# ## Github Link

# %%
# !git clone https://github.com/AarohiSingla/YOLO-v4-Implementation-on-Custom-Dataset.git
# Out:
# Cloning into 'YOLO-v4-Implementation-on-Custom-Dataset'...
# remote: Enumerating objects: 75, done.
# remote: Counting objects: 100% (75/75), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 75 (delta 10), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (75/75), done.

# %% [markdown]
# ## Local Drive

# %%
# %cd /content/drive/MyDrive/yolov4piford/dataSet/
# Out:
# /content/drive/MyDrive/yolov4piford/dataSet

# %% [markdown]
# ## This *is* **heading**

# %% [markdown]
# ```
# # This is formatted as code
# for item in list:
#         print(item)
# ```

# %% [markdown]
# ![846b10f97066825114bd7b1d771c8331.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# [gGoogle search](https://www.google.com)

# %% [markdown]
# *   first
# *   second
#
#
# > kikrghjkgk.q
#
#
# > kjregnklq

# %% [markdown]
# $ax^2+bx+c $
#
# $$x1=\frac{-b + \sqrt(b^2-4ac)}{2a}$$
